# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Part 2

# %%
df = pd.read_csv('assignment_3_2nd_iris_dataset.csv')

# %%
print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
print(df.shape)
# Out:
# (150, 6)

# %%
print(df.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
columns = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']

df[columns].describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Part 1

# %%
df_2 = pd.read_csv('assignment_5_Social_Network_Ads.csv')

# %%
print(df_2.head())
# Out:
#     User ID Gender  Age  EstimatedSalary Purchased
# 0  15624510      1   19            19000         0
# 1  15810944      1   35            20000         0
# 2  15668575      0   26            43000         0
# 3  15603246      0   27            57000         0
# 4  15804002      1   19            76000         0

# %%
print(df_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB
# None

# %%
print(df_2.describe())
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
print(df_2.dtypes)
# Out:
# User ID               int64
# Gender             category
# Age                   int64
# EstimatedSalary       int64
# Purchased          category
# dtype: object

# %%
print(df_2.isnull().sum())
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df_2['Gender'] = df_2['Gender'].astype('category')
df_2['Purchased'] = df_2['Purchased'].astype('category')

# %%
df_2['Gender'] = df_2['Gender'].replace(
    {
        'Male':1,
        "Female":0
    }
)
# Out:
# C:\Users\Pranav Deshmukh\AppData\Local\Temp\ipykernel_7144\2660051659.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_2['Gender'] = df_2['Gender'].replace(
# C:\Users\Pranav Deshmukh\AppData\Local\Temp\ipykernel_7144\2660051659.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df_2['Gender'] = df_2['Gender'].replace(

# %%
salary_by_gender = df.groupby('Gender')['EstimatedSalary'].agg(['mean','median','std','min','max'])

print(salary_by_gender)
# Out:
#                 mean   median           std    min     max
# Gender
# 0       71759.803922  70500.0  35595.236189  15000  150000
# 1       67642.857143  68000.0  32421.819181  15000  150000
# C:\Users\Pranav Deshmukh\AppData\Local\Temp\ipykernel_7144\3578264728.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   salary_by_gender = df.groupby('Gender')['EstimatedSalary'].agg(['mean','median','std','min','max'])

# %%
purchased_by_age = df.groupby('Purchased')['Age'].agg(['mean','median','std','min','max'])
print(purchased_by_age)
# Out:
#                 mean  median       std  min  max
# Purchased
# 0          32.793774    34.0  7.985844   18   59
# 1          46.391608    47.0  8.612172   27   60
# C:\Users\Pranav Deshmukh\AppData\Local\Temp\ipykernel_7144\1982755970.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   purchased_by_age = df.groupby('Purchased')['Age'].agg(['mean','median','std','min','max'])
