# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("assignment_1_dirty_cafe_sales.csv")

# %%
print(df.head())
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          0.0
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    Payment Method  Location     Transaction Date
# 0     Credit Card       1.0  2023-09-08 00:00:00
# 1            Cash       0.0  2023-05-16 00:00:00
# 2     Credit Card       0.0  2023-07-19 00:00:00
# 3         UNKNOWN       0.0  2023-04-27 00:00:00
# 4  Digital Wallet       0.0  2023-06-11 00:00:00

# %%
print(df.shape)
# Out:
# (10000, 8)

# %%
print(df.dtypes)
# Out:
# Transaction ID              object
# Item                      category
# Quantity                   float64
# Price Per Unit             float64
# Total Spent                float64
# Payment Method            category
# Location                   float64
# Transaction Date    datetime64[ns]
# dtype: object

# %%
df['Quantity'] = pd.to_numeric(df['Quantity'],errors="coerce")
df['Price Per Unit'] = pd.to_numeric(df['Price Per Unit'],errors="coerce")
df['Total Spent'] =pd.to_numeric(df['Total Spent'],errors="coerce")
df['Transaction Date']= pd.to_datetime(df['Transaction Date'],errors="coerce")
df['Item']= df['Item'].astype('category')
df['Payment Method']=df['Payment Method'].astype('category')

# %%
print(df.isnull().sum())
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df['Location'] = df['Location'].map(
    {
        'In-Store':0,
        'Takeaway':1
    }
)

# %%
print(df['Location'].value_counts())
# Out:
# Location
# 0.0    6978
# 1.0    3022
# Name: count, dtype: int64
