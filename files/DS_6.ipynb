# %%
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score

# %%
df = pd.read_csv('assignment_6_iris_dataset.csv')

# %%
print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
print(df.shape)
# Out:
# (150, 6)

# %%
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
print(df.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
print(df.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
x = df.drop('Species',axis=1)

y = df['Species']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = GaussianNB()

model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(x_test)

print(y_pred[:5])
# Out:
# ['Iris-versicolor' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-versicolor']

# %%
cm = confusion_matrix(y_test, y_pred,
labels=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'])

print(cm)
# Out:
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
for i in range(len(cm)):
    tp = cm[i,i]
    fp = cm[:,i].sum() - tp
    fn = cm[i,:].sum()- tp
    tn = cm.sum() - (tp+fp+fn)

print(tp,fp,fn,tn)
# Out:
# 11 0 0 19

# %%
accuracy = (tp + tn) / (tp + fp +fn+tn)
print(accuracy)
# Out:
# 1.0

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
precision = tp / (tp + fp)
print(precision)
print(precision_score(y_test,y_pred))
# Out:
# 1.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 precision = tp / (tp + fp)
#       2 print(precision)
# ----> 3 print(precision_score(y_test,y_pred))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:2247, in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2079 @validate_params(
#    2080     {
#    2081         "y_true": ["array-like", "sparse matrix"],
#    (...)   2106     zero_division="warn",
#    2107 ):
#    2108     """Compute the precision.
#    2109
#    2110     The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)   2245     array([0.5, 1. , 1. ])
#    2246     """
# -> 2247     p, _, _, _ = precision_recall_fscore_support(
#    2248         y_true,
#    2249         y_pred,
#    2250         labels=labels,
#    2251         pos_label=pos_label,
#    2252         average=average,
#    2253         warn_for=("precision",),
#    2254         sample_weight=sample_weight,
#    2255         zero_division=zero_division,
#    2256     )
#    2257     return p
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 global_skip_validation = get_config()["skip_parameter_validation"]
#     188 if global_skip_validation:
# --> 189     return func(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1830, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1661 """Compute precision, recall, F-measure and support for each class.
#    1662
#    1663 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)   1827  array([2, 2, 2]))
#    1828 """
#    1829 _check_zero_division(zero_division)
# -> 1830 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1832 # Calculate tp_sum, pred_sum, true_sum ###
#    1833 samplewise = average == "samples"
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1613, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1611         if y_type == "multiclass":
#    1612             average_options.remove("samples")
# -> 1613         raise ValueError(
#    1614             "Target is %s but average='binary'. Please "
#    1615             "choose another average setting, one of %r." % (y_type, average_options)
#    1616         )
#    1617 elif pos_label not in (None, 1):
#    1618     warnings.warn(
#    1619         "Note that pos_label (set to %r) is ignored when "
#    1620         "average != 'binary' (got %r). You may use "
#    (...)   1623         UserWarning,
#    1624     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
recall = tp / (tp + fn)
print(recall)
# Out:
# 1.0

# %%
print(classification_report(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(classification_report(y_test,y_pred))
#
# NameError: name 'classification_report' is not defined
